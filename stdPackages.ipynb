# %%
import os 
c = os.getcwd()
os.chdir(os.path.dirname(c))
# %run stdPackages.ipynb
d['figs'] = os.path.join(c, 'Figs')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\CAAL\Anaconda3\lib\site-packages\IPython\core\magics\execution.py:697, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     696     fpath = arg_lst[0]
# --> 697     filename = file_finder(fpath)
#     698 except IndexError as e:
#
# File c:\Users\CAAL\Anaconda3\lib\site-packages\IPython\utils\path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'stdPackages.ipynb'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# c:\Users\CAAL\Dropbox\Polit\Kandidat\4. semester\EE of the GT\Greenland\Codes\Greenland\stdPackages.ipynb Cell 1 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/stdPackages.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> c = os.getcwd()
#       <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/stdPackages.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> os.chdir(os.path.dirname(c))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/stdPackages.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> get_ipython().run_line_magic('run', 'stdPackages.ipynb')
#       <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/stdPackages.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> d['figs'] = os.path.join(c, 'Figs')
#
# File c:\Users\CAAL\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2369, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2367     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2368 with self.builtin_trap:
# -> 2369     result = fn(*args, **kwargs)
#    2371 # The code below prevents the output from being displayed
#    2372 # when using magics with decodator @output_can_be_silenced
#    2373 # when the last Python token in the expression is a ';'.
#    2374 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\CAAL\Anaconda3\lib\site-packages\IPython\core\magics\execution.py:708, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     706     if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     707         warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 708     raise Exception(msg) from e
#     709 except TypeError:
#     710     if fpath in sys.meta_path:
#
# Exception: File `'stdPackages.ipynb'` not found.

# %% [markdown]
# Settings for plots:

# %%
def largeFont():
    SMALL_SIZE = 24
    MEDIUM_SIZE = 28
    BIGGER_SIZE = 32
    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
    plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
def one_graph():
    SMALL_SIZE = 19
    MEDIUM_SIZE = 22
    BIGGER_SIZE = 25
    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
    plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
def mult_graphs():
    SMALL_SIZE = 16
    MEDIUM_SIZE = 19
    BIGGER_SIZE = 22
    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
    plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\CAAL\Dropbox\Polit\Kandidat\4. semester\EE of the GT\Greenland\Codes\Greenland\sd.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> {
#       <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a>  "cells": [
#       <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a>   {
#       <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a>    "cell_type": "code",
#       <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a>    "execution_count": 1,
#       <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a>    "id": "5ad53db0-482c-4531-abaf-3e7846333113",
#       <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a>    "metadata": {},
#       <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a>    "outputs": [],
#       <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a>    "source": [
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a>     "import os \n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a>     "c = os.getcwd()\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a>     "os.chdir(os.path.dirname(c))\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a>     "%run stdPackages.ipynb\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a>     "d['figs'] = os.path.join(c, 'Figs')"
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a>    ]
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=15'>16</a>   },
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a>   {
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=17'>18</a>    "cell_type": "markdown",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=18'>19</a>    "id": "51db8b64-1763-476b-aa46-6997f1e37544",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=19'>20</a>    "metadata": {},
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=20'>21</a>    "source": [
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=21'>22</a>     "Settings for plots:"
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=22'>23</a>    ]
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=23'>24</a>   },
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=24'>25</a>   {
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=25'>26</a>    "cell_type": "code",
# ---> <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=26'>27</a>    "execution_count": null,
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=27'>28</a>    "id": "b5b5b5fb-e5cc-453e-b25f-18107ee1c8a1",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=28'>29</a>    "metadata": {},
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=29'>30</a>    "outputs": [],
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=30'>31</a>    "source": [
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=31'>32</a>     "def largeFont():\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=32'>33</a>     "    SMALL_SIZE = 24\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=33'>34</a>     "    MEDIUM_SIZE = 28\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=34'>35</a>     "    BIGGER_SIZE = 32\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=35'>36</a>     "    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=36'>37</a>     "    plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=37'>38</a>     "    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=38'>39</a>     "    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=39'>40</a>     "    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=40'>41</a>     "    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=41'>42</a>     "    plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=42'>43</a>     "def one_graph():\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=43'>44</a>     "    SMALL_SIZE = 19\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=44'>45</a>     "    MEDIUM_SIZE = 22\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=45'>46</a>     "    BIGGER_SIZE = 25\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=46'>47</a>     "    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=47'>48</a>     "    plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=48'>49</a>     "    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=49'>50</a>     "    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=50'>51</a>     "    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=51'>52</a>     "    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=52'>53</a>     "    plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=53'>54</a>     "def mult_graphs():\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=54'>55</a>     "    SMALL_SIZE = 16\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=55'>56</a>     "    MEDIUM_SIZE = 19\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=56'>57</a>     "    BIGGER_SIZE = 22\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=57'>58</a>     "    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=58'>59</a>     "    plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=59'>60</a>     "    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=60'>61</a>     "    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=61'>62</a>     "    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=62'>63</a>     "    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize\n",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=63'>64</a>     "    plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title    "
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=64'>65</a>    ]
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=65'>66</a>   }
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=66'>67</a>  ],
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=67'>68</a>  "metadata": {
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=68'>69</a>   "kernelspec": {
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=69'>70</a>    "display_name": "Python 3 (ipykernel)",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=70'>71</a>    "language": "python",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=71'>72</a>    "name": "python3"
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=72'>73</a>   },
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=73'>74</a>   "language_info": {
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=74'>75</a>    "codemirror_mode": {
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=75'>76</a>     "name": "ipython",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=76'>77</a>     "version": 3
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=77'>78</a>    },
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=78'>79</a>    "file_extension": ".py",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=79'>80</a>    "mimetype": "text/x-python",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=80'>81</a>    "name": "python",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=81'>82</a>    "nbconvert_exporter": "python",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=82'>83</a>    "pygments_lexer": "ipython3",
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=83'>84</a>    "version": "3.11.3"
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=84'>85</a>   }
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=85'>86</a>  },
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=86'>87</a>  "nbformat": 4,
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=87'>88</a>  "nbformat_minor": 5
#      <a href='vscode-notebook-cell:/c%3A/Users/CAAL/Dropbox/Polit/Kandidat/4.%20semester/EE%20of%20the%20GT/Greenland/Codes/Greenland/sd.ipynb#W0sZmlsZQ%3D%3D?line=88'>89</a> }
#
# NameError: name 'null' is not defined
